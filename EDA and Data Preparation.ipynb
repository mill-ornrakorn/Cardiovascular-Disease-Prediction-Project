# %%
import pandas as pd
cardio_df = pd.read_csv(r'cardio_train.csv', sep=';')
cardio_df = cardio_df.drop(columns='id')
cardio_df.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  18393       2     168    62.0    110     80            1     1      0
# 1  20228       1     156    85.0    140     90            3     1      0
# 2  18857       1     165    64.0    130     70            3     1      0
# 3  17623       2     169    82.0    150    100            1     1      0
# 4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
cardio_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          70000 non-null  int64
#  1   gender       70000 non-null  int64
#  2   height       70000 non-null  int64
#  3   weight       70000 non-null  float64
#  4   ap_hi        70000 non-null  int64
#  5   ap_lo        70000 non-null  int64
#  6   cholesterol  70000 non-null  int64
#  7   gluc         70000 non-null  int64
#  8   smoke        70000 non-null  int64
#  9   alco         70000 non-null  int64
#  10  active       70000 non-null  int64
#  11  cardio       70000 non-null  int64
# dtypes: float64(1), int64(11)
# memory usage: 6.4 MB

# %%
cardio_df.isnull().any()
# Out:
# id             False
# age            False
# gender         False
# height         False
# weight         False
# ap_hi          False
# ap_lo          False
# cholesterol    False
# gluc           False
# smoke          False
# alco           False
# active         False
# cardio         False
# dtype: bool

# %%
cardio_df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   19468.865814      1.349571    164.359229     74.205690    128.817286
# std     2467.251667      0.476838      8.210126     14.395757    154.011419
# min    10798.000000      1.000000     55.000000     10.000000   -150.000000
# 25%    17664.000000      1.000000    159.000000     65.000000    120.000000
# 50%    19703.000000      1.000000    165.000000     72.000000    120.000000
# 75%    21327.000000      2.000000    170.000000     82.000000    140.000000
# max    23713.000000      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      1.226457      0.088129      0.053771
# ...

# %%
cardio_df.query("ap_hi <= -100")
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 4607   15281       1     165    78.0   -100     80            2     1      0
# 16021  22108       2     161    90.0   -115     70            1     1      0
# 20536  15581       1     153    54.0   -100     70            1     1      0
# 23988  18301       1     162    74.0   -140     90            1     1      0
# 25240  14711       2     168    50.0   -120     80            2     1      0
# 35040  23325       2     168    59.0   -150     80            1     1      0
# 46627  23646       2     160    59.0   -120     80            1     1      0
#
#        alco  active  cardio
# 4607      0       1       0
# 16021     0       1       0
# 20536     0       1       0
# 23988     0       1       1
# 25240     0       0       1
# 35040     0       1       1
# 46627     0       0       0

# %%
cardio_df.query("ap_lo >= 1000")
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 228    17489       2     183    98.0    160   1100            1     2      1
# 241    21932       2     157    60.0    160   1000            2     1      0
# 329    23407       1     176    63.0    160   1000            2     2      0
# 345    18704       1     154    81.0    140   1000            2     1      0
# 473    15226       1     150    95.0    150   1033            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69771  23330       1     167    81.0    160   1000            1     1      0
# 69872  21808       1     152    56.0    160   1000            1     1      0
# 69878  21239       2     168    95.0    160   1000            1     1      0
# 69885  22417       2     166    78.0    170   1000            1     1      0
# 69967  21416       2     168    63.0    140   1000            1     1      0
#
#        alco  active  cardio
# ...

# %%
cardio_feature = cardio_df.iloc[:,:-1]
cardio_result = cardio_df.iloc[:,-1]

# %%
cardio_feature["age"] = cardio_feature["age"].apply(lambda x : x/365)
cardio_feature
# Out:
#              age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0      50.391781       2     168    62.0    110     80            1     1
# 1      55.419178       1     156    85.0    140     90            3     1
# 2      51.663014       1     165    64.0    130     70            3     1
# 3      48.282192       2     169    82.0    150    100            1     1
# 4      47.873973       1     156    56.0    100     60            1     1
# ...          ...     ...     ...     ...    ...    ...          ...   ...
# 69995  52.712329       2     168    76.0    120     80            1     1
# 69996  61.920548       1     158   126.0    140     90            2     2
# 69997  52.235616       2     183   105.0    180     90            3     1
# 69998  61.454795       1     163    72.0    135     80            1     2
# 69999  56.273973       1     170    72.0    120     80            2     1
#
#        smoke  alco  active
# 0          0     0       1
# ...

# %%
cardio_df.drop(cardio_df[cardio_df['ap_hi'] <= 80].index, inplace=True)

# %%
cardio_df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  69689.000000  69689.000000  69689.000000  69689.000000  69689.000000
# mean   19470.523741      1.349625    164.362812     74.221646    129.233193
# std     2466.408676      0.476855      8.197113     14.396679    154.205411
# min    10798.000000      1.000000     55.000000     10.000000     85.000000
# 25%    17667.000000      1.000000    159.000000     65.000000    120.000000
# 50%    19704.000000      1.000000    165.000000     72.000000    120.000000
# 75%    21328.000000      2.000000    170.000000     82.000000    140.000000
# max    23713.000000      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  69689.000000  69689.000000  69689.000000  69689.000000  69689.000000
# mean      96.629282      1.367289      1.226435      0.088149      0.053696
# ...

# %%
cardio_df.drop(cardio_df[cardio_df['ap_hi'] >= 180].index, inplace=True)

# %%
cardio_df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  68625.000000  68625.000000  68625.000000  68625.000000  68625.000000
# mean   19458.395672      1.348736    164.374208     74.085337    126.209996
# std     2467.999502      0.476574      8.178983     14.280472     15.453699
# min    10798.000000      1.000000     55.000000     11.000000     85.000000
# 25%    17651.000000      1.000000    159.000000     65.000000    120.000000
# 50%    19697.000000      1.000000    165.000000     72.000000    120.000000
# 75%    21319.000000      2.000000    170.000000     82.000000    140.000000
# max    23713.000000      2.000000    250.000000    200.000000    179.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  68625.000000  68625.000000  68625.000000  68625.000000  68625.000000
# mean      94.568991      1.362958      1.224233      0.087650      0.053319
# ...

# %%
cardio_df.drop(cardio_df[cardio_df['ap_lo'] <= 60].index, inplace=True)

# %%
cardio_df.describe()
# Out:
#                 age        gender        height       weight         ap_hi  \
# count  65821.000000  65821.000000  65821.000000  65821.00000  65821.000000
# mean   19496.928746      1.353216    164.462755     74.40531    127.104237
# std     2456.480000      0.477973      8.159341     14.25557     14.844138
# min    10859.000000      1.000000     55.000000     11.00000     85.000000
# 25%    17737.000000      1.000000    159.000000     65.00000    120.000000
# 50%    19718.000000      1.000000    165.000000     72.00000    120.000000
# 75%    21344.000000      2.000000    170.000000     82.00000    140.000000
# max    23713.000000      2.000000    250.000000    200.00000    179.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  65821.000000  65821.000000  65821.000000  65821.000000  65821.000000
# mean      96.087328      1.368378      1.227025      0.088072      0.053797
# ...

# %%
cardio_df.drop(cardio_df[cardio_df['ap_lo'] >= 110].index, inplace=True)

# %%
cardio_df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  64586.000000  64586.000000  64586.000000  64586.000000  64586.000000
# mean   19492.459217      1.351841    164.455315     74.264562    126.648577
# std     2458.711906      0.477548      8.149208     14.153589     14.439413
# min    10859.000000      1.000000     55.000000     11.000000     85.000000
# 25%    17722.250000      1.000000    159.000000     65.000000    120.000000
# 50%    19717.000000      1.000000    165.000000     72.000000    120.000000
# 75%    21343.000000      2.000000    170.000000     82.000000    140.000000
# max    23713.000000      2.000000    250.000000    200.000000    179.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  64586.000000  64586.000000  64586.000000  64586.000000  64586.000000
# mean      81.790806      1.364460      1.225715      0.087620      0.053185
# ...

# %%
#cardio_df.query("height >= 55 and height <=100")

# %%
cardio_df['BMI'] = cardio_df['weight']/((cardio_df['height']/100)**2)
cardio_df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio        BMI
# ...

# %%
cardio_df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   19468.865814      1.349571    164.359229     74.205690    128.817286
# std     2467.251667      0.476838      8.210126     14.395757    154.011419
# min    10798.000000      1.000000     55.000000     10.000000   -150.000000
# 25%    17664.000000      1.000000    159.000000     65.000000    120.000000
# 50%    19703.000000      1.000000    165.000000     72.000000    120.000000
# 75%    21327.000000      2.000000    170.000000     82.000000    140.000000
# max    23713.000000      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      1.226457      0.088129      0.053771
# ...

# %%
#cardio_df.drop(cardio_df[cardio_df['height'] >= 110].index, inplace=True)

# %%
cardio_df.query("BMI >= 3 and BMI <=15")
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 5362   16755       1     167    41.0    110     80            1     1      0
# 6486   21220       1     250    86.0    140    100            3     1      0
# 9487   20958       2     172    40.0    140     90            1     2      0
# 10447  22007       1     162    38.0    100     70            1     1      0
# 12920  15574       2     174    45.0    130    100            2     2      0
# 16225  19621       1     196    56.0    125     80            1     1      0
# 16322  21872       1     165    35.0    100     70            1     1      0
# 16906  17272       2     170    31.0    150     90            2     2      0
# 18559  18140       1     160    30.0    120     80            1     1      0
# 22307  21228       1     169    42.0    150     90            2     2      0
# 26806  23284       1     157    23.0    110     80            1     1      0
# ...

# %%
cardio_df.query("BMI >= 60 and BMI <=300")
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 224    21800       2      76    55.0    120     80            1     1      0
# 389    16718       2     165   169.0    120     80            1     1      0
# 2458   23646       2     159   165.0    130     70            1     1      0
# 3413   14585       1     159   159.0    100     80            1     1      0
# 3420   14516       1     100    70.0    100     70            1     1      0
# 6153   20990       1     122   161.0    120     80            1     1      0
# 8171   17646       2      97   170.0    160    100            1     1      1
# 8677   19698       2     119    89.0    160     90            1     1      0
# 11230  18307       1     110    90.0    120     80            1     1      0
# 12435  22077       1     137   161.0    150    100            2     1      0
# 12770  19594       1      75   168.0    120     80            1     1      1
# ...

# %%
cardio_df.drop(cardio_df[cardio_df['BMI'] >= 40].index, inplace=True)

# %%
cardio_df.drop(cardio_df[cardio_df['BMI'] <= 16 ].index, inplace=True)

# %%
cardio_df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  68054.000000  68054.000000  68054.000000  68054.000000  68054.000000
# mean   19460.274664      1.355468    164.566462     73.209474    128.396083
# std     2469.114008      0.478658      7.811408     12.808913    148.138052
# min    10798.000000      1.000000    120.000000     28.000000   -150.000000
# 25%    17652.000000      1.000000    159.000000     65.000000    120.000000
# 50%    19697.000000      1.000000    165.000000     72.000000    120.000000
# 75%    21320.000000      2.000000    170.000000     81.000000    140.000000
# max    23713.000000      2.000000    207.000000    135.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  68054.000000  68054.000000  68054.000000  68054.000000  68054.000000
# mean      95.903415      1.359582      1.221545      0.089106      0.053751
# ...

# %%
cardio_df.query("height >= 250")
# Out:
#         age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 6486  21220       1     250    86.0    140    100            3     1      0
#
#       alco  active  cardio    BMI
# 6486     0       1       1  13.76

# %%
cardio_df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  62879.000000  62879.000000  62879.000000  62879.000000  62879.000000
# mean   19485.220312      1.357607    164.654909     73.322374    126.441562
# std     2460.242538      0.479300      7.773116     12.663163     14.349783
# min    10859.000000      1.000000    120.000000     28.000000     85.000000
# 25%    17703.000000      1.000000    159.000000     65.000000    120.000000
# 50%    19712.000000      1.000000    165.000000     72.000000    120.000000
# 75%    21337.000000      2.000000    170.000000     81.000000    140.000000
# max    23713.000000      2.000000    207.000000    135.000000    179.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  62879.000000  62879.000000  62879.000000  62879.000000  62879.000000
# mean      81.697562      1.357433      1.221107      0.088583      0.053261
# ...

# %%
cardio_df.drop('height', inplace=True, axis=1)

# %%
cardio_df
# Out:
#          age  gender  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0      18393       2    62.0    110     80            1     1      0     0
# 1      20228       1    85.0    140     90            3     1      0     0
# 2      18857       1    64.0    130     70            3     1      0     0
# 3      17623       2    82.0    150    100            1     1      0     0
# 5      21914       1    67.0    120     80            2     2      0     0
# ...      ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69993  19699       1    70.0    130     90            1     1      0     0
# 69994  21074       1    80.0    150     80            1     1      0     0
# 69995  19240       2    76.0    120     80            1     1      1     0
# 69998  22431       1    72.0    135     80            1     2      0     0
# 69999  20540       1    72.0    120     80            2     1      0     0
#
#        active  cardio        BMI
# 0           1       0  21.967120
# ...

# %%
cardio_df.drop('weight', inplace=True, axis=1)

# %%
cardio_df
# Out:
#          age  gender  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active  \
# 0      18393       2    110     80            1     1      0     0       1
# 1      20228       1    140     90            3     1      0     0       1
# 2      18857       1    130     70            3     1      0     0       0
# 3      17623       2    150    100            1     1      0     0       1
# 5      21914       1    120     80            2     2      0     0       0
# ...      ...     ...    ...    ...          ...   ...    ...   ...     ...
# 69993  19699       1    130     90            1     1      0     0       1
# 69994  21074       1    150     80            1     1      0     0       1
# 69995  19240       2    120     80            1     1      1     0       1
# 69998  22431       1    135     80            1     2      0     0       0
# 69999  20540       1    120     80            2     1      0     0       1
#
#        cardio        BMI
# 0           0  21.967120
# ...

# %%
cardio_df['cardio'].value_counts()
# Out:
# 0    31821
# 1    31058
# Name: cardio, dtype: int64

# %%
import seaborn as sns
cardio_plot = sns.countplot(data = cardio_df, y ='cardio',palette="Set2")
cardio_plot.set_xlabel("Number of patients")
cardio_plot.set_ylabel("Presence or absence of cardiovascular disease")
# Out:
# Text(0, 0.5, 'Presence or absence of cardiovascular disease')

# %%
cardio_df.to_csv('cardio_train_cleaned.csv', index=False)

# %%
import pandas as pd
cardio_train_cleaned = pd.read_csv('cardio_train_cleaned.csv')
cardio_train_cleaned.head()
# Out:
#      age  gender  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active  \
# 0  18393       2    110     80            1     1      0     0       1
# 1  20228       1    140     90            3     1      0     0       1
# 2  18857       1    130     70            3     1      0     0       0
# 3  17623       2    150    100            1     1      0     0       1
# 4  21914       1    120     80            2     2      0     0       0
#
#    cardio        BMI
# 0       0  21.967120
# 1       1  34.927679
# 2       1  23.507805
# 3       1  28.710479
# 4       0  29.384676

# %%
cardio_train_cleaned.describe()
# Out:
#                 age        gender         ap_hi         ap_lo   cholesterol  \
# count  62879.000000  62879.000000  62879.000000  62879.000000  62879.000000
# mean   19485.220312      1.357607    126.441562     81.697562      1.357433
# std     2460.242538      0.479300     14.349783      7.695989      0.674775
# min    10859.000000      1.000000     85.000000     61.000000      1.000000
# 25%    17703.000000      1.000000    120.000000     80.000000      1.000000
# 50%    19712.000000      1.000000    120.000000     80.000000      1.000000
# 75%    21337.000000      2.000000    140.000000     90.000000      1.000000
# max    23713.000000      2.000000    179.000000    109.000000      3.000000
#
#                gluc         smoke          alco        active        cardio  \
# count  62879.000000  62879.000000  62879.000000  62879.000000  62879.000000
# mean       1.221107      0.088583      0.053261      0.804227      0.493933
# ...

# %%
cardio_train_cleaned['gender'] = cardio_train_cleaned['gender'].replace({1:0, 2:1})
cardio_train_cleaned['cholesterol'] = cardio_train_cleaned['cholesterol'].replace({1:0, 2:1, 3:2})
cardio_train_cleaned['gluc'] = cardio_train_cleaned['gluc'].replace({1:0, 2:1, 3:2})

# %%
cardio_train_cleaned
# Out:
#          age  gender  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active  \
# 0      18393       1    110     80            0     0      0     0       1
# 1      20228       0    140     90            2     0      0     0       1
# 2      18857       0    130     70            2     0      0     0       0
# 3      17623       1    150    100            0     0      0     0       1
# 4      21914       0    120     80            1     1      0     0       0
# ...      ...     ...    ...    ...          ...   ...    ...   ...     ...
# 62874  19699       0    130     90            0     0      0     0       1
# 62875  21074       0    150     80            0     0      0     0       1
# 62876  19240       1    120     80            0     0      1     0       1
# 62877  22431       0    135     80            0     1      0     0       0
# 62878  20540       0    120     80            1     0      0     0       1
#
#        cardio        BMI
# 0           0  21.967120
# ...

# %%
cardio_df["age"] = cardio_df["age"].apply(lambda x : x/365)
cardio_df
# Out:
#              age  gender  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0      50.391781       1    110     80            0     0      0     0
# 1      55.419178       0    140     90            2     0      0     0
# 2      51.663014       0    130     70            2     0      0     0
# 3      48.282192       1    150    100            0     0      0     0
# 4      60.038356       0    120     80            1     1      0     0
# ...          ...     ...    ...    ...          ...   ...    ...   ...
# 62874  53.969863       0    130     90            0     0      0     0
# 62875  57.736986       0    150     80            0     0      0     0
# 62876  52.712329       1    120     80            0     0      1     0
# 62877  61.454795       0    135     80            0     1      0     0
# 62878  56.273973       0    120     80            1     0      0     0
#
#        active  cardio        BMI
# 0           1       0  21.967120
# 1           1       1  34.927679
# ...

# %%
#cardio_train_cleaned.to_csv('cardio_train_cleaned_2.csv', index=False)

# %%
import pandas as pd
cardio_train_cleaned = pd.read_csv('cardio_train_cleaned_2.csv')
cardio_train_cleaned.head()
# Out:
#          age  gender  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active  \
# 0  50.391781       1    110     80            0     0      0     0       1
# 1  55.419178       0    140     90            2     0      0     0       1
# 2  51.663014       0    130     70            2     0      0     0       0
# 3  48.282192       1    150    100            0     0      0     0       1
# 4  60.038356       0    120     80            1     1      0     0       0
#
#    cardio        BMI
# 0       0  21.967120
# 1       1  34.927679
# 2       1  23.507805
# 3       1  28.710479
# 4       0  29.384676

# %%
cardio_train_cleaned.describe()
# Out:
#                 age        gender         ap_hi         ap_lo   cholesterol  \
# count  62879.000000  62879.000000  62879.000000  62879.000000  62879.000000
# mean      53.384165      0.357607    126.441562     81.697562      0.357433
# std        6.740391      0.479300     14.349783      7.695989      0.674775
# min       29.750685      0.000000     85.000000     61.000000      0.000000
# 25%       48.501370      0.000000    120.000000     80.000000      0.000000
# 50%       54.005479      0.000000    120.000000     80.000000      0.000000
# 75%       58.457534      1.000000    140.000000     90.000000      0.000000
# max       64.967123      1.000000    179.000000    109.000000      2.000000
#
#                gluc         smoke          alco        active        cardio  \
# count  62879.000000  62879.000000  62879.000000  62879.000000  62879.000000
# mean       0.221107      0.088583      0.053261      0.804227      0.493933
# ...

# %%
cardio_train_cleaned['cardio'].value_counts()
# Out:
# 0    31821
# 1    31058
# Name: cardio, dtype: int64

# %%
import seaborn as sns
cardio_plot = sns.countplot(data = cardio_train_cleaned, y ='cardio',palette="Set2")
cardio_plot.set_xlabel("Number of patients")
cardio_plot.set_ylabel("Presence or absence of cardiovascular disease")
# Out:
# Text(0, 0.5, 'Presence or absence of cardiovascular disease')

# %%
import seaborn as sns
sns.boxplot(data = cardio_train_cleaned, x = 'ap_hi', palette="Set2")
# Out:
# <AxesSubplot:xlabel='ap_hi'>

# %%
import seaborn as sns
sns.boxplot(data = cardio_train_cleaned, x = 'ap_lo', palette="Set2")
# Out:
# <AxesSubplot:xlabel='ap_lo'>

# %%
import pandas as pd
cardio_df2 = pd.read_csv(r'cardio_train - Copy.csv', sep=';')
cardio_df2.head()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80          1.0     1      0
# 1   1  20228       1     156    85.0    140     90          NaN     1      0
# 2   2  18857       1     165    64.0    130     70          3.0     1      0
# 3   3  17623       2     169    82.0    150    100          1.0     1      0
# 4   4  17474       1     156    56.0    100     60          1.0     1      0
#
#   alco  active  cardio
# 0    0       1     NaN
# 1    0       1     1.0
# 2    0       0     1.0
# 3    0       1     1.0
# 4    0       0     0.0

# %%
cardio_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  69999 non-null  float64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  object
#  11  active       70000 non-null  int64
#  12  cardio       69998 non-null  float64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 6.9+ MB

# %%
cardio_df2.isnull().any()
# Out:
# id             False
# age            False
# gender         False
# height         False
# weight         False
# ap_hi          False
# ap_lo          False
# cholesterol     True
# gluc           False
# smoke          False
# alco           False
# active         False
# cardio          True
# dtype: bool

# %% [markdown]
# ---

# %%
import pandas as pd
cardio_df = pd.read_csv(r'cardio_train.csv', sep=';')
cardio_df = cardio_df.drop(columns='id')
cardio_df.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  18393       2     168    62.0    110     80            1     1      0
# 1  20228       1     156    85.0    140     90            3     1      0
# 2  18857       1     165    64.0    130     70            3     1      0
# 3  17623       2     169    82.0    150    100            1     1      0
# 4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
cardio_df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   19468.865814      1.349571    164.359229     74.205690    128.817286
# std     2467.251667      0.476838      8.210126     14.395757    154.011419
# min    10798.000000      1.000000     55.000000     10.000000   -150.000000
# 25%    17664.000000      1.000000    159.000000     65.000000    120.000000
# 50%    19703.000000      1.000000    165.000000     72.000000    120.000000
# 75%    21327.000000      2.000000    170.000000     82.000000    140.000000
# max    23713.000000      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      1.226457      0.088129      0.053771
# ...

# %%
cardio_df["age"] = cardio_df["age"].apply(lambda x : x/365)
cardio_df
# Out:
#              age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0      50.391781       2     168    62.0    110     80            1     1
# 1      55.419178       1     156    85.0    140     90            3     1
# 2      51.663014       1     165    64.0    130     70            3     1
# 3      48.282192       2     169    82.0    150    100            1     1
# 4      47.873973       1     156    56.0    100     60            1     1
# ...          ...     ...     ...     ...    ...    ...          ...   ...
# 69995  52.712329       2     168    76.0    120     80            1     1
# 69996  61.920548       1     158   126.0    140     90            2     2
# 69997  52.235616       2     183   105.0    180     90            3     1
# 69998  61.454795       1     163    72.0    135     80            1     2
# 69999  56.273973       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 0          0     0       1       0
# ...

# %%
import seaborn as sns
sns.boxplot(data = cardio_feature, x = 'age', palette="Paired")
# Out:
# <AxesSubplot:xlabel='age'>

# %%
import seaborn as sns
sns.boxplot(data = cardio_df, x = 'height', palette="Set2")
# Out:
# <AxesSubplot:xlabel='height'>

# %%
import seaborn as sns
sns.boxplot(data = cardio_df, x = 'weight', palette="Paired")
# Out:
# <AxesSubplot:xlabel='weight'>

# %%
import seaborn as sns
sns.boxplot(data = cardio_df, x = 'ap_hi', palette="Set2")

# %%
import seaborn as sns
sns.boxplot(data = cardio_df, x = 'ap_lo', palette="Set2")
# Out:
# <AxesSubplot:xlabel='ap_lo'>

# %% [markdown]
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt
age_plot = sns.distplot(cardio_feature['age'], 
             bins=20, 
             kde=False, 
             hist_kws={'edgecolor':'black'}
            )
age_plot.set_xlabel("Age (years)")
age_plot.set_ylabel("Number of patients")
# Out:
# Text(0, 0.5, 'Number of patients')

# %%
cardio_feature['gender'].value_counts()
# Out:
# 1    45530
# 2    24470
# Name: gender, dtype: int64

# %%
gender_plot = sns.countplot(data = cardio_feature, y = 'gender',palette="husl")
gender_plot.set_xlabel("Number of patients")
gender_plot.set_ylabel("Gender")
# Out:
# Text(0, 0.5, 'Gender')

# %%
import seaborn as sns
height_plot = sns.distplot(cardio_feature['height'], 
             bins=20, 
             kde=False, 
             color="purple",
             hist_kws={'edgecolor':'black'})

height_plot.set_xlabel("Height (cm)")
height_plot.set_ylabel("Number of patients")
# Out:
# Text(0, 0.5, 'Number of patients')

# %%
import seaborn as sns
weight_plot = sns.distplot(cardio_feature['weight'], 
             bins=20, 
             kde=False, 
             color="y",
             hist_kws={'edgecolor':'black'})

weight_plot.set_xlabel("Weight (kg)")
weight_plot.set_ylabel("Number of patients")
# Out:
# Text(0, 0.5, 'Number of patients')

# %%
import seaborn as sns
ap_hi_plot = sns.distplot(cardio_feature['ap_hi'], 
             bins=20, 
             kde=False, 
             color="r",
             hist_kws={'edgecolor':'black'})

# %%
import seaborn as sns
ap_hi_plot = sns.distplot(cardio_feature['ap_hi'], 
             bins=20, 
             kde=False, 
             color="r",
             hist_kws={'edgecolor':'black'})

ap_hi_plot.set_xlabel("Weight (kg)")
ap_hi_plot.set_ylabel("Number of patients")
ap_hi_plot.set_xlim(-1000, 1000)
# Out:
# (-1000.0, 1000.0)

# %%
import seaborn as sns
ap_hi_plot = sns.distplot(cardio_feature['ap_hi'], 
             bins=20, 
             kde=False, 
             color="r",
             hist_kws={'edgecolor':'black'})

ap_hi_plot.set_xlabel("Weight (kg)")
ap_hi_plot.set_ylabel("Number of patients")
ap_hi_plot.set_xlim(-1000, 1000)

# %%
cholesterol_plot = sns.countplot(data = cardio_feature, y = 'cholesterol',palette="YlOrBr")
cholesterol_plot.set_xlabel("Number of patients")
cholesterol_plot.set_ylabel("Cholesterol")
# Out:
# Text(0, 0.5, 'Cholesterol')

# %%
gluc_plot = sns.countplot(data = cardio_feature, y = 'gluc',palette="Blues")
gluc_plot.set_xlabel("Number of patients")
gluc_plot.set_ylabel("Glucose")
# Out:
# Text(0, 0.5, 'Glucose')

# %%
cardio_feature['gluc'].value_counts()
# Out:
# 1    59479
# 3     5331
# 2     5190
# Name: gluc, dtype: int64

# %%
smoke_plot = sns.countplot(data = cardio_feature, y = 'smoke',palette="coolwarm")
smoke_plot.set_xlabel("Number of patients")
smoke_plot.set_ylabel("Smoking")
# Out:
# Text(0, 0.5, 'Smoking')

# %%
alco_plot = sns.countplot(data = cardio_feature, y = 'alco',palette="dark:salmon_r")
alco_plot.set_xlabel("Number of patients")
alco_plot.set_ylabel("Alcohol intake")
# Out:
# Text(0, 0.5, 'Alcohol intake')

# %%
active_plot = sns.countplot(data = cardio_feature, y = 'active',palette="Spectral")
active_plot.set_xlabel("Number of patients")
active_plot.set_ylabel("Physical activity")
# Out:
# Text(0, 0.5, 'Physical activity')

# %%
cardio_df['cardio'].value_counts()
# Out:
# 0    35021
# 1    34979
# Name: cardio, dtype: int64

# %%
cardio_plot = sns.countplot(data = cardio_df, y ='cardio',palette="Set2")
cardio_plot.set_xlabel("Number of patients")
cardio_plot.set_ylabel("Presence or absence of cardiovascular disease")
# Out:
# Text(0, 0.5, 'Presence or absence of cardiovascular disease')
